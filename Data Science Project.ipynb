# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.sankey import Sankey

# %% [markdown]
# # Import Data

# %%
speciesgroup1 ="https://raw.githubusercontent.com/Shane2019/DataScienceProject/master/Speciesgroup1.csv"
speciesgroup1 =pd.read_csv(speciesgroup1)
print(speciesgroup1)
# Out:
#               Sepcies  01/02/2019  15/02/2019  08/03/2019
# 0        Ruminococcus          16          50           7
# 1         Coprococcus          56          74          29
# 2     Lachnospiraceae          27          19          80
# 3               S24-7           4          49          85
# 4               S24-7          23           1          57
# 5     Ruminococcaceae          87          12          45
# 6               S24-7          44          29          83
# 7               S24-7          48          68           5
# 8               S24-7          50          51          18
# 9     Lachnospiraceae           6          16          22
# 10    Ruminococcaceae          25          19          12
# 11              S24-7         120          36          32
# 12              S24-7          38          10         131
# 13  Enterobacteraceae         137          60           2
# 14              S24-7          25          95          83

# %%
speciesgroup2 ="https://raw.githubusercontent.com/Shane2019/DataScienceProject/master/Speciesgroup2.csv"
speciesgroup2 =pd.read_csv(speciesgroup2)
print(speciesgroup2)
# Out:
#             Sepcies  08/02/2019  22/02/2019  08/03/2019
# 0             S24-7          87           2          83
# 1             S24-7          31          13          91
# 2              RF32          39           4          88
# 3     Clostridiales          24          56          65
# 4             S24-7          54          48          47
# 5      Helicobacter          35          45          16
# 6             S24-7          64          10          12
# 7             S24-7          15           6          19
# 8             S24-7           2          19          14
# 9   Lachnospiraceae          25          46          46
# 10    Clostridiales          16          43           7
# 11    Clostridiales          43         108          12
# 12    Clostridiales           1         111          37
# 13    Clostridiales           3          35         143
# 14     Ruminococcus          83          57         120

# %% [markdown]
# # Time Series Analysis

# %%
speciesgroup1.plot(kind = 'bar', legend = True, color=['r','g','b'], title = 'Abundance of Species Recorded')

# %%
speciesgroup2.plot(kind = 'bar', legend = True, color=['r','g','b'], title = 'Abundance of Species Recorded')

# %%
speciesdf ="https://raw.githubusercontent.com/Shane2019/DataScienceProject/master/Species.csv"
speciesdf =pd.read_csv(speciesdf)
print(speciesdf)
# Out:
#               Sepcies  Abundance        Date
# 0        Ruminococcus         16  01/02/2019
# 1         Coprococcus         56  01/02/2019
# 2     Lachnospiraceae         27  01/02/2019
# 3               S24-7          4  01/02/2019
# 4               S24-7         23  01/02/2019
# 5     Ruminococcaceae         87  01/02/2019
# 6               S24-7         44  01/02/2019
# 7               S24-7         48  01/02/2019
# 8               S24-7         50  01/02/2019
# 9     Lachnospiraceae          6  01/02/2019
# 10    Ruminococcaceae         25  01/02/2019
# 11              S24-7        120  01/02/2019
# 12              S24-7         38  01/02/2019
# 13  Enterobacteraceae        137  01/02/2019
# 14              S24-7         25  01/02/2019
# 15              S24-7         87  08/02/2019
# 16              S24-7         31  08/02/2019
# 17               RF32         39  08/02/2019
# 18      Clostridiales         24  08/02/2019
# 19              S24-7         54  08/02/2019
# 20       Helicobacter         35  08/02/2019
# 21              S24-7         64  08/02/2019
# 22              S24-7         15  08/02/2019
# 23              S24-7          2  08/02/2019
# 24    Lachnospiraceae         25  08/02/2019
# 25      Clostridiales         16  08/02/2019
# 26      Clostridiales         43  08/02/2019
# 27      Clostridiales          1  08/02/2019
# 28      Clostridiales          3  08/02/2019
# 29       Ruminococcus         83  08/02/2019
# ..                ...        ...         ...
# 60       Ruminococcus          7  01/03/2019
# 61        Coprococcus         29  01/03/2019
# 62    Lachnospiraceae         80  01/03/2019
# 63              S24-7         85  01/03/2019
# 64              S24-7         57  01/03/2019
# 65    Ruminococcaceae         45  01/03/2019
# 66              S24-7         83  01/03/2019
# 67              S24-7          5  01/03/2019
# 68              S24-7         18  01/03/2019
# 69    Lachnospiraceae         22  01/03/2019
# 70    Ruminococcaceae         12  01/03/2019
# 71              S24-7         32  01/03/2019
# 72              S24-7        131  01/03/2019
# 73  Enterobacteraceae          2  01/03/2019
# 74              S24-7         83  01/03/2019
# 75              S24-7         83  08/03/2019
# 76              S24-7         91  08/03/2019
# 77               RF32         88  08/03/2019
# 78      Clostridiales         65  08/03/2019
# 79              S24-7         47  08/03/2019
# 80       Helicobacter         16  08/03/2019
# 81              S24-7         12  08/03/2019
# 82              S24-7         19  08/03/2019
# 83              S24-7         14  08/03/2019
# 84    Lachnospiraceae         46  08/03/2019
# 85      Clostridiales          7  08/03/2019
# 86      Clostridiales         12  08/03/2019
# 87      Clostridiales         37  08/03/2019
# 88      Clostridiales        143  08/03/2019
# 89       Ruminococcus        120  08/03/2019
#
# [90 rows x 3 columns]

# %% [markdown]
# #  Microbe Abundance Analysis

# %%
str(speciesdf)
speciesdf.plot.bar(stacked=True);
speciesdf.columns = ["Species","Abundance","Date"]

# %% [markdown]
# # Subset Analysis By Date

# %% [markdown]
# ## 1. 01/02/2019

# %%
species_0102 = speciesdf.loc[speciesdf['Date'] == '01/02/2019']
species_0102 = species_0102[['Species','Abundance']]
print(species_0102)
species_0102.set_index('Species',drop=True,inplace=True)
species_0102.plot(kind = 'bar', legend = True, color=['r'], title = 'Abundance of Species Recorded on 01/02/2019')
# Out:
#               Species  Abundance
# 0        Ruminococcus         16
# 1         Coprococcus         56
# 2     Lachnospiraceae         27
# 3               S24-7          4
# 4               S24-7         23
# 5     Ruminococcaceae         87
# 6               S24-7         44
# 7               S24-7         48
# 8               S24-7         50
# 9     Lachnospiraceae          6
# 10    Ruminococcaceae         25
# 11              S24-7        120
# 12              S24-7         38
# 13  Enterobacteraceae        137
# 14              S24-7         25

# %% [markdown]
# ## 2. 08/02/2019

# %%
species_0108 = speciesdf.loc[speciesdf['Date'] == '08/02/2019']
species_0108 = species_0108[['Species','Abundance']]
print(species_0108)
species_0108.set_index('Species',drop=True,inplace=True)
species_0108.plot(kind = 'bar', legend = True, color=['g'], title = 'Abundance of Species Recorded on 08/02/2019')
# Out:
#             Species  Abundance
# 15            S24-7         87
# 16            S24-7         31
# 17             RF32         39
# 18    Clostridiales         24
# 19            S24-7         54
# 20     Helicobacter         35
# 21            S24-7         64
# 22            S24-7         15
# 23            S24-7          2
# 24  Lachnospiraceae         25
# 25    Clostridiales         16
# 26    Clostridiales         43
# 27    Clostridiales          1
# 28    Clostridiales          3
# 29     Ruminococcus         83

# %% [markdown]
# ## 15/02/2019

# %%
species_1502 = speciesdf.loc[speciesdf['Date'] == '15/02/2019']
species_1502 = species_1502[['Species','Abundance']]
print(species_1502)
species_1502.set_index('Species',drop=True,inplace=True)
species_1502.plot(kind = 'bar', legend = True, color=['b'], title = 'Abundance of Species Recorded on 15/02/2019')
# Out:
#               Species  Abundance
# 30       Ruminococcus         50
# 31        Coprococcus         74
# 32    Lachnospiraceae         19
# 33              S24-7         49
# 34              S24-7          1
# 35    Ruminococcaceae         12
# 36              S24-7         29
# 37              S24-7         68
# 38              S24-7         51
# 39    Lachnospiraceae         16
# 40    Ruminococcaceae         19
# 41              S24-7         36
# 42              S24-7         10
# 43  Enterobacteraceae         60
# 44              S24-7         95

# %% [markdown]
# ##  4. 22/02/2019

# %%
species_2202 = speciesdf.loc[speciesdf['Date'] == '22/02/2019']
species_2202 = species_2202[['Species','Abundance']]
print(species_2202)
species_2202.set_index('Species',drop=True,inplace=True)
species_2202.plot(kind = 'bar', legend = True, color=['r'], title = 'Abundance of Species Recorded on 22/02/2019')
# Out:
#             Species  Abundance
# 45            S24-7          2
# 46            S24-7         13
# 47             RF32          4
# 48    Clostridiales         56
# 49            S24-7         48
# 50     Helicobacter         45
# 51            S24-7         10
# 52            S24-7          6
# 53            S24-7         19
# 54  Lachnospiraceae         46
# 55    Clostridiales         43
# 56    Clostridiales        108
# 57    Clostridiales        111
# 58    Clostridiales         35
# 59     Ruminococcus         57

# %% [markdown]
# ## 5. 01/03/2019

# %%
species_0103 = speciesdf.loc[speciesdf['Date'] == '01/03/2019']
species_0103 = species_0103[['Species','Abundance']]
print(species_0103)
species_0103.set_index('Species',drop=True,inplace=True)
species_0103.plot(kind = 'bar', legend = True, color=['g'], title = 'Abundance of Species Recorded on 01/03/2019')
# Out:
#               Species  Abundance
# 60       Ruminococcus          7
# 61        Coprococcus         29
# 62    Lachnospiraceae         80
# 63              S24-7         85
# 64              S24-7         57
# 65    Ruminococcaceae         45
# 66              S24-7         83
# 67              S24-7          5
# 68              S24-7         18
# 69    Lachnospiraceae         22
# 70    Ruminococcaceae         12
# 71              S24-7         32
# 72              S24-7        131
# 73  Enterobacteraceae          2
# 74              S24-7         83

# %% [markdown]
# ## 6. 08/03/2019

# %%
species_0803 = speciesdf.loc[speciesdf['Date'] == '08/03/2019']
species_0803 = species_0803[['Species','Abundance']]
print(species_0803)
species_0803.set_index('Species',drop=True,inplace=True)
species_0803.plot(kind = 'bar', legend = True, color=['g'], title = 'Abundance of Species Recorded on 08/03/2019')
# Out:
#             Species  Abundance
# 75            S24-7         83
# 76            S24-7         91
# 77             RF32         88
# 78    Clostridiales         65
# 79            S24-7         47
# 80     Helicobacter         16
# 81            S24-7         12
# 82            S24-7         19
# 83            S24-7         14
# 84  Lachnospiraceae         46
# 85    Clostridiales          7
# 86    Clostridiales         12
# 87    Clostridiales         37
# 88    Clostridiales        143
# 89     Ruminococcus        120
